# %%
import pandas as pd
import seaborn as sns
from datetime import datetime
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
sns.set()
plt.style.use('seaborn')
pd.options.plotting.backend = "plotly"
plt.rcParams["figure.figsize"] = (16, 8)
sns.set_palette("bright")

# %%
df = pd.read_csv('../../corpus/forums/drugsforumNL/threads/drugsforumnl.csv')
df['title'] = df['title'].str.lower()
df['content'] = df['content'].str.lower()

# %%
drug_names=['3mmc']

# %%
def get_drug_stats(drug_names):
    drug_df = pd.DataFrame(columns=df.columns)
    # run loop to search for every drug name
    for drug_name in drug_names:
        t_df = df[df['title'].str.contains(drug_name)]
        c_df = df[df['content'].str.contains(drug_name)]
        tc_df = pd.concat([t_df,c_df]).drop_duplicates().reset_index(drop=True)
        drug_df = pd.concat([drug_df, tc_df]).drop_duplicates().reset_index(drop=True)
    
    drug_df['month'] = drug_df['date'].apply(lambda x: int(x.split('-')[1]))
    drug_df['year'] = drug_df['date'].apply(lambda x: int(x.split('-')[0]))
    drug_df['month-year'] = drug_df['date'].apply(lambda x: x.split('-')[0] + '-' + x.split('-')[1])
    # print out information
    print('DRUG : ', '/'.join(drug_names))
    print('total occurences : ', drug_df.shape[0])
    print('total views :', drug_df['views'].sum())
    print('total comments :', drug_df['comments'].sum())
    
    
    data=drug_df.sort_values(by=['date'])
    
#     sns.lineplot(x=data['month'],
#                 y=pd.to_numeric(data['views']),
#                 hue=data['year'],
#                 legend='full',
#                 palette = sns.color_palette('rocket', n_colors=len(drug_df['year'].unique())))
    
    sns.lineplot(x=data['month-year'],
                y = pd.to_numeric(data['views'])
                )
    plt.title('views of posts related to ' + '/'.join(drug_names))
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2);

# %%
#drug_names = ['cocaine']
drug_names=['3mmc', '3-mmc']
get_drug_stats(drug_names)
# Out:
# DRUG :  3mmc/3-mmc
# total occurences :  317
# total views : 1328023
# total comments : 7365

# %%
drug_df
# Out:
#     thread_id       forum                                          title  \
# 0       73438  drugsforum  3mmc 1 gram eerste keer, volgende dag school.
# 1       73381  drugsforum                                 3mmc magnetron
# 2       73309  drugsforum                             3mmc oraal doseren
# 3       73261  drugsforum                                  3mmc dosering
# 4       73248  drugsforum           hees/zwaardere stem na 3mmc slikken?
# ..        ...         ...                                            ...
# 221     62792  drugsforum                  eerste keer hardrugs proberen
# 222     61681  drugsforum                 mxp (methoxphenidine) ervaring
# 223     59325  drugsforum   3-mmc versneden met heroine of valspositief?
# 224     54671  drugsforum                             research chemicals
# 225     52222  drugsforum                        'lichte' upper gezocht!
#
#                                                content views comments  \
# 0     ik wil volgende week zondag voor het eerst 3m...   295       12
# 1     hoi hoi,  lang niets gepost. 3mmc is heel pla...   567        9
# 2     hallo allemaal,  morgen staat er een hardstyl...   684       15
# 3     goedemorgen!  ik wil binnenkort 3mmc gaan sli...   764        5
# 4     hallo allemaal, eerste post hier dus vergeef ...  1000       21
# ..                                                 ...   ...      ...
# 221   hallo   ik heb net mijn account aangemaakt na...  3000       12
# 222   hallo allemaal, ben nieuw op dit forum, zoek ...  2000        1
# 223   beste,  ik had via een bekende (en ik denk al...  1000        1
# 224   hallo iemand ervaring heeft met 3mmc en ander...  1000        1
# 225   hallo!  ik werk s'nachts in een discotheek, p...  2000       14
#
#                                                    url     username user_id  \
# 0    https://drugsforum.nl/threads/3mmc-1-gram-eers...     sayoefie  156068
# 1    https://drugsforum.nl/threads/3mmc-magnetron.7...      Krullen  128087
# 2    https://drugsforum.nl/threads/3mmc-oraal-doser...    2C-Baasje  154352
# 3    https://drugsforum.nl/threads/3mmc-dosering.73...  qwertysafgo  155065
# 4    https://drugsforum.nl/threads/hees-zwaardere-s...     Nassauwe  156994
# ..                                                 ...          ...     ...
# 221  https://drugsforum.nl/threads/eerste-keer-hard...         Davy  142618
# 222  https://drugsforum.nl/threads/mxp-methoxphenid...       Bokter  141409
# 223  https://drugsforum.nl/threads/3-mmc-versneden-...    honolulu4  132755
# 224  https://drugsforum.nl/threads/research-chemica...      gerardo  118479
# 225  https://drugsforum.nl/threads/lichte-upper-gez...      OuweGek   58220
#
#                                               user_url        date
# 0       https://drugsforum.nl/members/sayoefie.156068/  2022-12-10
# 1        https://drugsforum.nl/members/krullen.128087/  2022-11-30
# 2      https://drugsforum.nl/members/2c-baasje.154352/  2022-11-18
# 3    https://drugsforum.nl/members/qwertysafgo.155065/  2022-11-10
# 4       https://drugsforum.nl/members/nassauwe.156994/  2022-11-07
# ..                                                 ...         ...
# 221         https://drugsforum.nl/members/davy.142618/  2018-03-26
# 222       https://drugsforum.nl/members/bokter.141409/  2017-09-08
# 223    https://drugsforum.nl/members/honolulu4.132755/  2016-06-04
# 224      https://drugsforum.nl/members/gerardo.118479/  2015-01-29
# 225       https://drugsforum.nl/members/ouwegek.58220/  2014-04-20
#
# [226 rows x 11 columns]
